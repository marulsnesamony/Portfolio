# %% [markdown]
# ###### Perform Hypothesis testing of the given dataset step-by-step to understand the factors influencing churn
# ###### The dataset consists of user activity logs from a navigation app. The objective is to identify factors that are capable of predicting user churn.
# ###### Dataset was provided as part of https://www.coursera.org/professional-certificates/google-advanced-data-analytics

# %%
import os
import pandas as pd
import numpy as np
